# %%
import string

# %%
input = open('14.txt').read().split('\n')

current = input
bool = True

while bool:
    new_grid = []
    for row_i, row in enumerate(current):
        new_row = ''
        if row_i == 0:
            for char_i, char in enumerate(row):
                if char == '.' and current[row_i+1][char_i] == 'O':
                    new_row += 'O'
                else:
                    new_row += char
        elif row_i == len(current) - 1:
            for char_i, char in enumerate(row):
                if char == 'O' and current[row_i-1][char_i] == '.':
                    new_row += '.'
                else:
                    new_row += char
        else:
            for char_i, char in enumerate(row):
                if char == '.' and current[row_i+1][char_i] == 'O':
                    new_row += 'O'
                elif char == 'O' and current[row_i-1][char_i] == '.':
                    new_row += '.'
                else:
                    new_row += char
        new_grid.append(new_row)
    if new_grid == current:
        bool = False
        current = new_grid
    else:
        current = new_grid

score = 0
multiplier = len(new_grid)
for row in current:
    score += row.count('O') * multiplier
    multiplier -= 1

score
# Out:
# 109385

# %% [markdown]
# # Part 2

# %%
def north_tilt(grid):
    new_grid = []
    for row_i, row in enumerate(grid):
        new_row = ''
        if row_i == 0:
            for char_i, char in enumerate(row):
                if char == '.' and grid[row_i+1][char_i] == 'O':
                    new_row += 'O'
                else:
                    new_row += char
        elif row_i == len(grid) - 1:
            for char_i, char in enumerate(row):
                if char == 'O' and grid[row_i-1][char_i] == '.':
                    new_row += '.'
                else:
                    new_row += char
        else:
            for char_i, char in enumerate(row):
                if char == '.' and grid[row_i+1][char_i] == 'O':
                    new_row += 'O'
                elif char == 'O' and grid[row_i-1][char_i] == '.':
                    new_row += '.'
                else:
                    new_row += char
        new_grid.append(new_row)
    return new_grid

def west_tilt(grid):
    new_grid = []
    for row_i, row in enumerate(grid):
        new_row = ''
        for char_i, char in enumerate(row):
            if char_i == 0:
                if char == '.' and row[1] == 'O':
                    new_row += 'O'
                else:
                    new_row += char
            elif char_i == len(row) - 1:
                if row[char_i-1] == '.' and char == 'O':
                    new_row += '.'
                else:
                    new_row += char
            else:
                if row[char_i-1] == '.' and char == 'O':
                    new_row += '.'
                elif row[char_i+1] == 'O' and char == '.':
                    new_row += 'O'
                else:
                    new_row += char
        new_grid.append(new_row)    
    return new_grid

def south_tilt(grid):
    new_grid = []
    for row_i, row in enumerate(grid):
        new_row = ''
        if row_i == 0:
            for char_i, char in enumerate(row):
                if char == 'O' and grid[row_i+1][char_i] == '.':
                    new_row += '.'
                else:
                    new_row += char
        elif row_i == len(grid) - 1:
            for char_i, char in enumerate(row):
                if char == '.' and grid[row_i-1][char_i] == 'O':
                    new_row += 'O'
                else:
                    new_row += char
        else:
            for char_i, char in enumerate(row):
                if char == 'O' and grid[row_i+1][char_i] == '.':
                    new_row += '.'
                elif char == '.' and grid[row_i-1][char_i] == 'O':
                    new_row += 'O'
                else:
                    new_row += char
        new_grid.append(new_row)
    return new_grid

def east_tilt(grid):
    new_grid = []
    for row_i, row in enumerate(grid):
        new_row = ''
        for char_i, char in enumerate(row):
            if char_i == 0:
                if char == 'O' and row[1] == '.':
                    new_row += '.'
                else:
                    new_row += char
            elif char_i == len(row) - 1:
                if row[char_i-1] == 'O' and char == '.':
                    new_row += 'O'
                else:
                    new_row += char
            else:
                if row[char_i-1] == 'O' and char == '.':
                    new_row += 'O'
                elif row[char_i+1] == '.' and char == 'O':
                    new_row += '.'
                else:
                    new_row += char
        new_grid.append(new_row)    
    return new_grid

# %%
current = input

for i in range(1000000000):
    if i % 50 == 0:
        print(i)
    current = east_tilt(south_tilt(west_tilt(north_tilt(current))))
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
# 1900
# 1950
# 2000
# 2050
# 2100
# 2150
# 2200
# 2250
# 2300
# 2350
# 2400
# 2450
# 2500
# 2550
# 2600
# 2650
# 2700
# 2750
# 2800
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 6
#       4 if i % 50 == 0:
#       5     print(i)
# ----> 6 current = east_tilt(south_tilt(west_tilt(north_tilt(current))))
#
# Cell In[23], line 71, in south_tilt(grid)
#      69 else:
#      70     for char_i, char in enumerate(row):
# ---> 71         if char == 'O' and grid[row_i+1][char_i] == '.':
#      72             new_row += '.'
#      73         elif char == '.' and grid[row_i-1][char_i] == 'O':
#
# KeyboardInterrupt:

# %%
from functools import cache

import numpy as np

with open("14.txt") as input_file:
    input_lines = input_file.readlines()
    input_lines = [line.strip('\n') for line in input_lines]

starting_grid = [list(line) for line in input_lines]
# starting_grid = np.array([list(line) for line in input_lines])
height, width = len(starting_grid), len(starting_grid[0])
# height, width = starting_grid.shape


# print("\n".join(map("".join, grid)))  # pretty print 2d character grid

def tupled(grid):
    return tuple(tuple(line) for line in grid)


@cache
def tilted_north(grid):
    next_grid = [["." for _ in range(width)] for _ in range(height)]
    for y in range(height):
        for x in range(width):
            if grid[y][x] == "#":
                next_grid[y][x] = "#"
            elif grid[y][x] == "O":
                first_empty_y_above = y
                while first_empty_y_above >= 0 and next_grid[first_empty_y_above][x] == ".":
                    first_empty_y_above -= 1
                first_empty_y_above += 1
                next_grid[first_empty_y_above][x] = "O"
    return next_grid


def calc_load(grid):
    total_load = 0
    for y in range(height):
        for x in range(width):
            if grid[y][x] == "O":
                total_load += height - y
    return total_load


print(calc_load(tilted_north(tupled(starting_grid))))  # Part 1:  109661


def iterate(grid):
    for j in range(4):
        # tilt
        grid = tupled(tilted_north(grid))
        # rotate clockwise
        grid = zip(*grid[::-1])
        # make tuple
        grid = tupled(grid)
    return grid


def iter_until_loop():
    seen_states = []
    grid = tupled(starting_grid)
    while True:
        if grid in seen_states:
            loop_start = seen_states.index(grid)
            loop_length = len(seen_states) - loop_start
            return loop_start, loop_length, seen_states
        seen_states.append(grid)
        grid = iterate(grid)


big_n = 1000000000
loop_start, loop_length, seen_states = iter_until_loop()
n = (big_n - loop_start) % loop_length
last_state = seen_states[loop_start + n]
print(calc_load(last_state))  # Part 2:  90176
# Out:
# 109385
# 93102
